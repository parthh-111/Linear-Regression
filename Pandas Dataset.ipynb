# %%
# Chp 3 Load a Dataset Using Pandas

import pandas as pd
data = pd.read_csv("student_scores.csv")
data.head(10)
print(data)
# Out:
#        name  hours  score gender grades class
# 0     Aarav      8     76      M      A    9A
# 1      Riya      5     62      F      B    9B
# 2     Kabir     10     88      M      A   10A
# 3      Sana      4     55      F      C    9A
# 4    Vivaan      7     72      M      B   10B
# ..      ...    ...    ...    ...    ...   ...
# 87   Prisha      4     52      F      C    9A
# 88     Neil     10     88      M      A   12C
# 89    Rutvi      7     73      F      B   10A
# 90  Harshit      5     57      M      C    9B
# 91   Vritti      8     81      F      A   11B
#
# [92 rows x 6 columns]

# %%
print("Columns:",data.columns.tolist())
print("\nIfo:")
print(data.info())
print("\nDEScribe:")
display
# Out:
# Columns: ['name', 'hours', 'score', 'gender', 'grades', 'class']
#
# Ifo:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    92 non-null     object
#  1   hours   92 non-null     int64
#  2   score   92 non-null     int64
#  3   gender  92 non-null     object
#  4   grades  92 non-null     object
#  5   class   92 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 4.4+ KB
# None
#
# DEScribe:
# <function IPython.core.display_functions.display(*objs, include=None, exclude=None, metadata=None, transient=None, display_id=None, raw=False, clear=False, **kwargs)>

# %%
print(data.isnull().sum())
data["score"] = data["score"].fillna(data["score"].mean())
data = data.dropna()
# Out:
# name      0
# hours     0
# score     0
# gender    0
# grades    0
# class     0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data["gender"] = le.fit_transform(data["gender"])
print(data.head(20))
# Out:
#        name  hours  score  gender grades class
# 0     Aarav      8     76       1      A    9A
# 1      Riya      5     62       0      B    9B
# 2     Kabir     10     88       1      A   10A
# 3      Sana      4     55       0      C    9A
# 4    Vivaan      7     72       1      B   10B
# 5    Ishita      6     64       0      B    9C
# 6     Rohan      3     48       1      D    9B
# 7     Meera      9     90       0      A   11A
# 8    Aditya      2     38       1      F    9C
# 9     Kavya     11     93       0      A   12A
# 10    Naman      5     60       1      B   10A
# 11   Jhanvi      7     70       0      B   11B
# 12   Pranav      4     52       1      C    9A
# 13     Tara      9     85       0      A   12B
# 14     Yash      6     66       1      B   10C
# 15    Anaya      8     78       0      A   11A
# 16    Harsh      3     45       1      D    9A
# 17     Diya     10     89       0      A   12C
# 18  Sarthak      6     63       1      B   10B
# 19    Manya      7     74       0      B   11B

# %%
le = LabelEncoder()
data["class_encoded"] = le.fit_transform(data["grades"])
print(data.head(20))
# Out:
#        name  hours  score  gender grades class  class_encoded
# 0     Aarav      8     76       1      A    9A              0
# 1      Riya      5     62       0      B    9B              1
# 2     Kabir     10     88       1      A   10A              0
# 3      Sana      4     55       0      C    9A              2
# 4    Vivaan      7     72       1      B   10B              1
# 5    Ishita      6     64       0      B    9C              1
# 6     Rohan      3     48       1      D    9B              3
# 7     Meera      9     90       0      A   11A              0
# 8    Aditya      2     38       1      F    9C              4
# 9     Kavya     11     93       0      A   12A              0
# 10    Naman      5     60       1      B   10A              1
# 11   Jhanvi      7     70       0      B   11B              1
# 12   Pranav      4     52       1      C    9A              2
# 13     Tara      9     85       0      A   12B              0
# 14     Yash      6     66       1      B   10C              1
# 15    Anaya      8     78       0      A   11A              0
# 16    Harsh      3     45       1      D    9A              3
# 17     Diya     10     89       0      A   12C              0
# 18  Sarthak      6     63       1      B   10B              1
# 19    Manya      7     74       0      B   11B              1

# %%
x = data[["hours" , "class_encoded"]]
y = data["score"]
print(x,y)
# Out:
#     hours  class_encoded
# 0       8              0
# 1       5              1
# 2      10              0
# 3       4              2
# 4       7              1
# ..    ...            ...
# 87      4              2
# 88     10              0
# 89      7              1
# 90      5              2
# 91      8              0
#
# [92 rows x 2 columns] 0     76
# 1     62
# 2     88
# 3     55
# 4     72
#       ..
# 87    52
# 88    88
# 89    73
# 90    57
# 91    81
# Name: score, Length: 92, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2,random_state=42)
print(x_train)
# Out:
#     hours  class_encoded
# 65      8              0
# 15      8              0
# 68      7              1
# 78      6              1
# 30      5              2
# ..    ...            ...
# 20      8              0
# 60      4              2
# 71      6              1
# 14      6              1
# 51     10              0
#
# [73 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)
print(x_train,x_test)
# Out:
# [[ 0.63215171 -1.07952032]
#  [ 0.63215171 -1.07952032]
#  [ 0.18412186 -0.10661929]
#  [-0.263908   -0.10661929]
#  [-0.71193785  0.86628174]
#  [ 0.18412186 -0.10661929]
#  [ 0.18412186 -0.10661929]
#  [-0.71193785  0.86628174]
#  [-1.15996771  0.86628174]
#  [ 1.08018157 -1.07952032]
#  [-1.15996771  0.86628174]
#  [ 1.97624128 -1.07952032]
#  [ 0.63215171 -0.10661929]
#  [-0.263908   -0.10661929]
#  [ 1.52821143 -1.07952032]
#  [-0.71193785 -0.10661929]
#  [-1.60799757  1.83918277]
#  [ 1.08018157 -1.07952032]
#  [-2.05602742  2.8120838 ]
#  [ 1.08018157 -1.07952032]
#  [-1.60799757  1.83918277]
#  [-1.60799757  1.83918277]
#  [ 0.18412186 -0.10661929]
#  [ 1.08018157 -1.07952032]
#  [ 0.18412186 -0.10661929]
#  [-0.71193785  0.86628174]
#  [ 1.08018157 -1.07952032]
#  [-1.15996771  0.86628174]
#  [-1.15996771  0.86628174]
#  [ 1.52821143 -1.07952032]
#  [-0.71193785  0.86628174]
#  [-2.05602742  2.8120838 ]
#  [ 1.52821143 -1.07952032]
#  [-1.60799757  1.83918277]
#  [ 1.52821143 -1.07952032]
#  [-0.263908   -0.10661929]
#  [ 0.63215171 -1.07952032]
#  [ 1.08018157 -1.07952032]
#  [ 0.63215171 -1.07952032]
#  [ 0.63215171 -0.10661929]
#  [-0.263908   -0.10661929]
#  [-1.15996771  1.83918277]
#  [-0.71193785  0.86628174]
#  [ 0.18412186 -0.10661929]
#  [-0.263908   -0.10661929]
#  [ 0.18412186 -0.10661929]
#  [-0.71193785  0.86628174]
#  [ 1.08018157 -1.07952032]
#  [-1.15996771  0.86628174]
#  [-0.71193785  0.86628174]
#  [ 0.63215171 -1.07952032]
#  [ 1.52821143 -1.07952032]
#  [-0.263908   -0.10661929]
#  [-1.15996771  0.86628174]
#  [-1.15996771  0.86628174]
#  [ 0.63215171 -1.07952032]
#  [ 1.52821143 -1.07952032]
#  [ 0.63215171 -0.10661929]
#  [ 1.08018157 -1.07952032]
#  [-0.263908   -0.10661929]
#  [-0.71193785 -0.10661929]
#  [ 0.18412186 -0.10661929]
#  [-0.71193785  0.86628174]
#  [ 1.52821143 -1.07952032]
#  [-0.263908   -0.10661929]
#  [-0.263908   -0.10661929]
#  [ 0.18412186 -0.10661929]
#  [ 0.18412186 -0.10661929]
#  [ 0.63215171 -1.07952032]
#  [-1.15996771  0.86628174]
#  [-0.263908   -0.10661929]
#  [-0.263908   -0.10661929]
#  [ 1.52821143 -1.07952032]] [[ 0.63215171 -1.07952032]
#  [ 1.08018157 -1.07952032]
#  [-1.60799757  1.83918277]
#  [-2.05602742  2.8120838 ]
#  [ 0.63215171 -1.07952032]
#  [ 0.63215171 -1.07952032]
#  [ 0.18412186 -0.10661929]
#  [ 1.08018157 -1.07952032]
#  [-0.71193785 -0.10661929]
#  [-1.60799757  1.83918277]
#  [-0.71193785  0.86628174]
#  [ 0.63215171 -0.10661929]
#  [ 0.18412186 -0.10661929]
#  [-1.60799757  1.83918277]
#  [-1.15996771  0.86628174]
#  [ 0.18412186 -0.10661929]
#  [-0.263908   -0.10661929]
#  [ 1.52821143 -1.07952032]
#  [-0.263908   -0.10661929]]

# %%
print("x_train shape:",x_train.shape)
print("x_test shape:",x_test.shape)
print("y_train shape:",y_train.shape)
print("y_test shape:",y_test.shape)
print("Mean",x_train_scaled.mean(axis=0))
print("std",x_train_scaled.std(axis=0))
# Out:
# x_train shape: (73, 2)
# x_test shape: (19, 2)
# y_train shape: (73,)
# y_test shape: (19,)
# Mean [-1.82502415e-17 -3.04170692e-18]
# std [1. 1.]
